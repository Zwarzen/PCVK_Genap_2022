# %% [markdown]
# <a href="https://colab.research.google.com/github/Zwarzen/PCVK_Genap_2022/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Inverse Citra

# %%
import cv2 
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

image_risang = cv2.imread('/content/drive/MyDrive/Images/gradient.jpg', 0)
inverted = np.invert(image_risang)
image_risang2 = image_risang #np.zeros(image_risang.shape, image_risang.dtype)

cv2.imwrite('inverted.jpg', inverted)
final_frame = cv2.hconcat((image_risang, inverted))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=L size=1920x540 at 0x7FAFD9858F10>

# %% [markdown]
# # Transformasi Log

# %%
#image_risang2 = image_risang #np.zeros(image_risang.shape, image_risang.dtype)

# Metode log transformation
rumus = 255 / np.log(1 + np.max(image_risang2))
log_gambar = rumus * (np.log(image_risang2 + 1))
   
# Spesifikasikan tipe data agar
# value dari float di konversi ke int
log_gambar = np.array(log_gambar, dtype = np.uint8)
   
# Display gambar
final_frame = cv2.hconcat((image_risang, log_gambar))
cv2_imshow(final_frame)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# <PIL.Image.Image image mode=L size=1920x540 at 0x7FAFD9858890>

# %% [markdown]
# # Gamma Correction

# %%
# print(' Gamma Correction pada citra ')
# print('----------------------------------')

# try:
  # gamma = int(input('Masukkan nilai Gamma: '))
# except ValueError:
  # print('Error, not a number')
# koreksi_gamma = np.zeros(image_risang.shape, image_risang.dtype)
# Trying 4 gamma values.
# for gamma in [0.1]: #0.1, 0.5, 1.2, 2.2
      
    # Apply gamma correction.
# koreksi_gamma = np.array(255*(image_risang2 / 255) ** gamma, dtype = 'uint8')
  
    # Save edited images.
# cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', koreksi_gamma)



# final_frame = cv2.hconcat((image_risang, koreksi_gamma))
# cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 2
# <PIL.Image.Image image mode=L size=1920x540 at 0x7FAFD98450D0>

# %% [markdown]
# # Image bit-Depth

# %%
mode_to_bpp = {'1':1, 'L':8, 'P':8, 'RGB':24, 'RGBA':32, 'CMYK':32, 'YCbCr':24, 'I':32, 'F':32}

#image_risang3 = (image_risang.depth)

cv2_imshow(image_risang)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7FAFD9D10B50>

# %% [markdown]
# # PSNR - Peak Signal-to-Noise Ratio

# %%
from math import log10, sqrt

def PSNR(image_risang, image_risang2):
    mse = np.mean((image_risang - image_risang2) ** 2)
    if(mse == 0):  # MSE adalah nol maka tidak ada suara pada sinyal .
                  # olehkarna itu PSNR tidak diperlukan.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr
  
def main():
     image_risang = cv2.imread("/content/drive/MyDrive/Images/gradient.jpg")
     image_risang2 = cv2.imread("/content/drive/MyDrive/Images/gradient.jpg", 1)
     value = PSNR(image_risang, image_risang2)
     print(f"PSNR value is {value} dB")
       
if __name__ == "__main__":
    main()
# Out:
# PSNR value is 100 dB

# %% [markdown]
# # Average Denoising

# %%
#import glob
img_risang = cv2.imread('/content/drive/MyDrive/Images/noises/1.jpg')
  
# denoising of image saving it into dst image
Average_Denoising = cv2.fastNlMeansDenoisingColored(img_risang, None, 10, 10, 7, 15)
  
# Plotting of source and destination image
# plt.subplot(121), plt.imshow(img_risang)
# plt.subplot(122), plt.imshow(Average_Denoising)

final_frame = cv2.hconcat((img_risang, Average_Denoising))
cv2_imshow(final_frame)
main()
# Out:
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAFD9489650>
# PSNR value is 100 dB

# %% [markdown]
# # Image Masking

# %% [markdown]
# # Tugas Praktikum
# - 1. Buat Gamma Correction sesuai dengan petunjuk berikut

# %%
img_risang2 = cv2.imread('/content/drive/MyDrive/Images/female.tiff')

print(' Gamma Correction pada citra ')
print('----------------------------------')

try:
  gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
  print('Error, not a number')
koreksi_gamma = np.zeros(img_risang2.shape, img_risang2.dtype)
# Trying 4 gamma values.
# for gamma in [0.1]: #0.1, 0.5, 1.2, 2.2
      
    # Apply gamma correction.
koreksi_gamma = np.array(255*(img_risang2 / 255) ** gamma, dtype = 'uint8')
  
    # Save edited images.
cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', koreksi_gamma)

final_frame = cv2.hconcat((img_risang2, koreksi_gamma))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FAFD97D6F50>

# %% [markdown]
# - 2. Buat Simulasi Image Depth

# %%
# img_risang2 = cv2.imread('/content/drive/MyDrive/Images/female.tiff')

print(' Gamma Correction pada citra ')
print('----------------------------------')

try:
  gamma = int(input('Masukkan nilai Depth: '))
except ValueError:
  print('Error, not a number')
koreksi_depth = np.zeros(img_risang2.shape, img_risang2.dtype)

mode_to_bpp = {'1':1, 'L':8, 'P':8, 'RGB':24, 'RGBA':32, 'CMYK':32, 'YCbCr':24, 'I':32, 'F':32}

#image_risang3 = (image_risang.depth)

cv2_imshow(image_risang)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a75549677f2> in <module>()
#       8 except ValueError:
#       9   print('Error, not a number')
# ---> 10 koreksi_gamma = np.zeros(img_risang2.shape, img_risang2.dtype)
#      11
#      12 mode_to_bpp = {'1':1, 'L':8, 'P':8, 'RGB':24, 'RGBA':32, 'CMYK':32, 'YCbCr':24, 'I':32, 'F':32}
#
# NameError: name 'np' is not defined

# %% [markdown]
# - 3. Buat modul Average Denoising

# %%
# denoising of image saving it into dst image
Average_Denoising = cv2.fastNlMeansDenoisingColored(img_risang, None, 10, 10, 7, 15)
  
# Plotting of source and destination image
# plt.subplot(121), plt.imshow(img_risang)
# plt.subplot(122), plt.imshow(Average_Denoising)

final_frame = cv2.hconcat((img_risang, Average_Denoising))
cv2_imshow(final_frame)
main()

# %% [markdown]
# - 4. Buat image masking untuk image berikut. Image kiri adalah image asli (images/teeth.jpg)

# %% [markdown]
# - 5. Lakukan percobaan menggunakan operator lain dan tunjukkan hasilnya pada modul ini. Tuliskan hasil analisa anda kenapa citra keluarannya seperti itu.
