# %% [markdown]
# <a href="https://colab.research.google.com/github/Zwarzen/PCVK_Genap_2022/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah (Step) 1

# %%
import numpy as np
import pandas as pd 
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image 
import matplotlib.pylab as plt

# %% [markdown]
# Langkah (Step) 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]
# Baca dan tampilkan image
# Loop pada tiap url image, beberapa image dapat disimpen pada list
for url in urls:
  image = io.imread(url)                          # Read Image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # Resize Image to Half
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # Convert Color to RGB
  final_frame = cv.hconcat((image, image_2))      # concatenate Image
  cv2_imshow(final_frame)                         # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7FD5A8B7C350>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD5A820FCD0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD5A822F150>

# %% [markdown]
# Langkah (Step) 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image : tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7FD5A61AFC90>

# %% [markdown]
# Langkah (Step) 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD5A8B6AF90>

# %% [markdown]
# Pertanyaan :
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# Jawab : karena lebih mudah diakses dimanapun tanpa harus instalasi software atau persiapan lainnya
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawab :
# - numpy : manipulasi library array, digunakan pada Aljabar Linear, Transform, dan kemungkinan angka acak
# - Pandas : Manipulasi data dan analisis
# - cv2 : untuk Computer Vision Tasks
# - Skimage : image prosesing pada Python
# - Matplotlib : alat Menghasilkan figur dan grafik user interface
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut, Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# Jawab : Mengubah ukuran gambar menjadi setengah, kegunaannya agar ukuran gambar tidak offset
#
# 4. Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab : sebagai marker warna
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawab : semakin besar resolusi gambar semakin banyak pixel yang menyusun gambar tsb, resolusi juga penentu kualitas gambar terlihat tajam atau tidak

# %% [markdown]
# Tugas, Buat garis Silang dan garis vertikal

# %%
# Membuat garis vertical ditengah gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255] # membuat garis horizontal, [y, int((lebar)/2)] mengubah posisi y ke belakang int((lebar)/2) 
                                             # akan mengubah koordinat garis

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# Membuat garis menyilang diagonal pada gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

first_line = (0,0)  # firstline = koordinat
#first_line2 = (400,0)

second_line = (400,286)
#second_line2 = (0,286)

cv.line(image_3, first_line, second_line, (255,255,255), 2)
#cv.line(image_3, first_line2, second_line2, (255,255,255), 2) 

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD5A58C3350>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FD5A58C3050>
